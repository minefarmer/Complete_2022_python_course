# %% [markdown]
# # Python Flow Control = Part 1A
# # if, else, elif

# %% [markdown]
# Control Flow
# Conditional Statements
# For Loops
# While Loops

# %% [markdown]
# #           Conditional Statements
#
# By default, statements in the script are executed sequentially from the first to the last.
#
# If the processing logic requires so, the sequentiql flow can be altered in two ways:
#
#         Conditional execution: a block of one or more statements will be executed if a certain expression is True.
#
#         Repetitive execution: a block of one or more statements will be reptitively ececuted as long as a certain expression is true.
#
# In this section you'll learn the decision control if, else, elif statements in Python. The comparision and logic operators are useful in controlling flow of the program.
#
# Python uses the if keyword to implement decision control. Python's syntax for executing a block vonditionally is:
#
#         Syntax
#     if[boolean expression]:
#         statement1
#         statement2
#         .......
#         statementN
#
#
# Any Booloean expression evaluating True or False appears after the if keyword. One or more statements written with the same level of indent will be executed if the Boolean expression evaluates to  True.
#
# To end the block, decrease the indention. Subsequent statements after the block will be executed out of the if condition.
#     Ex--------->    if 10<100>
#                     print("10 is less than 100"
#
# In This example, the expression 10<100 evaluates to True, so it will execute the block. The if block starts from new line after:   All the statements under the if condition start with the increased indention.
#
#
#
# Let's assume that we have to write a Python program that calculates the price and quantity and applies a 10% discount if the amount exceeds 1000 dollars.
# Calculation and application of the discount is to be done only if the amount is greater than 1000, so the process is placed in a block with increased indent, following the conditional expression.
# The print statement is written after the contitonal block is over, so it will be executed if the expression is false (i.e. the amount is not greater than 100), as well as after applying the discount if the expression is true.
#
#
#             If statement
#
# Here are the two scenarios of running the code. First one, data for price and quantity are greater than 1000. The amount after applying the discount is shown.
#
#             price=int(input("Enter Price: "))
#             qty=int(input("Enter quanty: "))
#             amt=price*qty
#             if amount>1000:
#                 print("10% discount is applicable")
#                 discount=amt*10/1000
#                 amount=amt-discount
#             print("Amount payable: ", amt)
#
#         # Data for price and quantity are greater than 1000.
#             enter Price: 1000
#             Enter Quantity: 20
#             10% discount is applicable
#             Amount payable: 1800.00
#
#
# In the second case, data is shown to be not true. The print statement will display the payable amount, which will not have a discount.
#
#         Enter Price: 10
#         Enter Quantity: 20
#         Amount payable: 200
#
#
#
#             Conditional Statements = else  **************************************************************
#
# Along with the if statement, the else condition can be used to define an alternate block of statements to be executed if the boolean expression in the if condition is not true.
#
# The indented block starts after the : symbol, after the boolean expression. It will get executed when the condition is true. We have another block block that should be executed when the if condition is false.
#
# Let's complete the if block by backspace and write else, add the : symbol in front of the new block to begin it and add the required statements in the block.
#
#         Syntax
#     if [boolean expression]:
#         statement1
#         statement2
#         ...
#         statementN
#
#
#
# De-dent the else block and enter thestatements that should be executed, regardless of the boolean expression being true or false.
#
# The condition 10>100 is False, so Python will execute the else block.
#
#     if 10>100:
#         print("10 is greater than 100")
#     else:
#         print("10 is less than 100")
#             Output
#     10 is less than 100
#
#
#
#             Conditional Statements = elif ********************************************************
#
# The elif condition is used to include multiple conditional expressions between if and else.
#
#         Syntax
#     if[boolean expression]:
#         [statements]
#     elif [boolean expresion]:
#         [statements]
#     elif [boolean expresion]:
#         [statements]
#     elif [boolean expresion]:
#         [statements]
#     else:
#         [statements]
#
# The elif block is exicuted if the specified ondition is true.
#
#     x=10
#     if x==1:
#         print('X is 1')
#     elif x==5:
#         print('X is 5')
#     elif x ==10:
#         print('X is 10')
#     else:
#         print('X is something else')
#           Output
#     10 is less than 100
#
# Above example, multiple elif conditions are applied between if and else. Python will execute the elif
